# %% [markdown]
# # **Exploratory Data Analysis using Pandas,Matplotlib and Seaborn**
#
# EDA on Laptop Price prediction Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns #advanced visualization library

# %%
df=pd.read_csv("/content/drive/MyDrive/ArtificialIntelligence/DataSets/laptop_data.csv")

# %%
df
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.drop(columns=["Unnamed: 0"],inplace=True)
df.head(3)
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz  8GB            128GB SSD
# 1        Intel Core i5 1.8GHz  8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz  8GB            256GB SSD
#
#                             Gpu  OpSys  Weight       Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg  71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg  47895.5232
# 2         Intel HD Graphics 620  No OS  1.86kg  30636.0000

# %%
df['Ram']
# Out:
# 0        8GB
# 1        8GB
# 2        8GB
# 3       16GB
# 4        8GB
#         ...
# 1298     4GB
# 1299    16GB
# 1300     2GB
# 1301     6GB
# 1302     4GB
# Name: Ram, Length: 1303, dtype: object

# %% [markdown]
#  **Analysing column by column**

# %%
df['Ram'].value_counts()
# Out:
# Ram
# 8GB     619
# 4GB     375
# 16GB    200
# 6GB      41
# 12GB     25
# 2GB      22
# 32GB     17
# 24GB      3
# 64GB      1
# Name: count, dtype: int64

# %%
s='16GB'
s.replace('GB','')
# Out:
# '16'

# %%
df['Ram']= df['Ram'].str.replace('GB','')
df['Weight']=df['Weight'].str.replace('kg','')

# %%
df.head(3)
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight       Price
# 0  Intel Iris Plus Graphics 640  macOS   1.37  71378.6832
# 1        Intel HD Graphics 6000  macOS   1.34  47895.5232
# 2         Intel HD Graphics 620  No OS   1.86  30636.0000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   object
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   object
#  10  Price             1303 non-null   float64
# dtypes: float64(2), object(9)
# memory usage: 112.1+ KB

# %%
df['Ram']=df['Ram'].astype('int')
df['Weight']=df['Weight'].astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int64
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float64
#  10  Price             1303 non-null   float64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 112.1+ KB

# %%
sns.displot(df['Price'],kde=True)

# %%
df['Company'].value_counts()
# Out:
# Company
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: count, dtype: int64

# %%
df['Company'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Company'>

# %%
sns.barplot(x=df['Company'],y=df['Price'],order=df['Company'].value_counts().index)
plt.xticks(rotation=90)
plt.show()

# %%
df['TypeName']
# Out:
# 0                Ultrabook
# 1                Ultrabook
# 2                 Notebook
# 3                Ultrabook
# 4                Ultrabook
#                ...
# 1298    2 in 1 Convertible
# 1299    2 in 1 Convertible
# 1300              Notebook
# 1301              Notebook
# 1302              Notebook
# Name: TypeName, Length: 1303, dtype: object

# %%
df['TypeName'].value_counts()
# Out:
# TypeName
# Notebook              727
# Gaming                205
# Ultrabook             196
# 2 in 1 Convertible    121
# Workstation            29
# Netbook                25
# Name: count, dtype: int64

# %%
df['TypeName'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='TypeName'>

# %%
sns.barplot(x=df['TypeName'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
df['Inches']
# Out:
# 0       13.3
# 1       13.3
# 2       15.6
# 3       15.4
# 4       13.3
#         ...
# 1298    14.0
# 1299    13.3
# 1300    14.0
# 1301    15.6
# 1302    15.6
# Name: Inches, Length: 1303, dtype: float64

# %%
df['Inches'].value_counts()
# Out:
# Inches
# 15.6    665
# 14.0    197
# 13.3    164
# 17.3    164
# 12.5     39
# 11.6     33
# 12.0      6
# 13.5      6
# 13.9      6
# 12.3      5
# 10.1      4
# 15.4      4
# 15.0      4
# 13.0      2
# 18.4      1
# 17.0      1
# 14.1      1
# 11.3      1
# Name: count, dtype: int64

# %%
df['Inches'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Inches'>

# %%
sns.displot(df['Inches'],kde=True)

# %%
sns.barplot(x=df['Inches'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
sns.scatterplot(x=df['Inches'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
df['Ram'].value_counts()
# Out:
# Ram
# 8     619
# 4     375
# 16    200
# 6      41
# 12     25
# 2      22
# 32     17
# 24      3
# 64      1
# Name: count, dtype: int64

# %%
df['Ram'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Ram'>

# %%
sns.barplot(x=df['Ram'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
df['OpSys']
# Out:
# 0            macOS
# 1            macOS
# 2            No OS
# 3            macOS
# 4            macOS
#            ...
# 1298    Windows 10
# 1299    Windows 10
# 1300    Windows 10
# 1301    Windows 10
# 1302    Windows 10
# Name: OpSys, Length: 1303, dtype: object

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         27
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
df['OpSys'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='OpSys'>

# %%
#does not make proper impact
sns.barplot(x=df['OpSys'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
#reduce the number of category
#write a function to categorize

def cat_os(inp):
  if inp == 'Windows 10' or inp == 'Windows 10 s' or inp == 'Windows 7':
    return 'Windows'
  elif inp == 'macOS' or inp == 'Mac OS X':
    return 'Mac OS'
  else:
    return 'Others/Linux/No OS'

# %%
cat_os('Windows 10')
# Out:
# 'Windows'

# %%
df['OpSys']=df['OpSys'].apply(cat_os)

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows               1117
# Others/Linux/No OS     165
# Mac OS                  21
# Name: count, dtype: int64

# %%
df['OpSys'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='OpSys'>

# %%
sns.barplot(x=df['OpSys'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
df['Weight']
# Out:
# 0       1.37
# 1       1.34
# 2       1.86
# 3       1.83
# 4       1.37
#         ...
# 1298    1.80
# 1299    1.30
# 1300    1.50
# 1301    2.19
# 1302    2.20
# Name: Weight, Length: 1303, dtype: float64

# %%
df['Weight'].value_counts()
# Out:
# Weight
# 2.20    126
# 2.10     58
# 2.00     45
# 2.40     44
# 2.30     41
#        ...
# 4.50      1
# 1.14      1
# 3.80      1
# 3.25      1
# 2.34      1
# Name: count, Length: 171, dtype: int64

# %%
#171 different categories continuous column no point in drawing bar graph rather we can draw displot
sns.displot(df['Weight'],kde=True)
plt.show()

# %%
#price prediction barplot doesn't make sense barplot will not give proper result because it's continuous commodity we use scatter plot
sns.scatterplot(x=df['Weight'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

#there is no linear relation weight may not have that much amount of correlation with price very random

# %%
df['Gpu']
# Out:
# 0       Intel Iris Plus Graphics 640
# 1             Intel HD Graphics 6000
# 2              Intel HD Graphics 620
# 3                 AMD Radeon Pro 455
# 4       Intel Iris Plus Graphics 650
#                     ...
# 1298           Intel HD Graphics 520
# 1299           Intel HD Graphics 520
# 1300               Intel HD Graphics
# 1301              AMD Radeon R5 M330
# 1302               Intel HD Graphics
# Name: Gpu, Length: 1303, dtype: object

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
df['Gpu'].value_counts().sample(10)
# Out:
# Gpu
# Nvidia Quadro M2000M             2
# Nvidia GeForce GTX 980M         10
# AMD Radeon R2 Graphics           4
# Intel HD Graphics 530            1
# AMD FirePro W4190M               1
# Nvidia GeForce MX130             6
# AMD Radeon R5 520                1
# Intel Iris Plus Graphics 650     2
# Nvidia GeForce GTX1050 Ti        1
# Intel HD Graphics 405            9
# Name: count, dtype: int64

# %%
#first name out of the whole graphics card
df['Gpu'].str.split()
# Out:
# 0       [Intel, Iris, Plus, Graphics, 640]
# 1              [Intel, HD, Graphics, 6000]
# 2               [Intel, HD, Graphics, 620]
# 3                  [AMD, Radeon, Pro, 455]
# 4       [Intel, Iris, Plus, Graphics, 650]
#                        ...
# 1298            [Intel, HD, Graphics, 520]
# 1299            [Intel, HD, Graphics, 520]
# 1300                 [Intel, HD, Graphics]
# 1301               [AMD, Radeon, R5, M330]
# 1302                 [Intel, HD, Graphics]
# Name: Gpu, Length: 1303, dtype: object

# %%
df['Gpu'].str.split()[0]
# Out:
# ['Intel', 'Iris', 'Plus', 'Graphics', '640']

# %%
df['Gpu'].str.split()[0][0]
# Out:
# 'Intel'

# %%
a = 'Intel, Iris, Plus, Graphics, 640'

# %%
(lambda x:x.split()[0])(a)
# Out:
# 'Intel,'

# %%
#pass the whole function to whole column
#remove or erase other things
df['Gpu'].apply(lambda x:x.split()[0])
# Out:
# 0       Intel
# 1       Intel
# 2       Intel
# 3         AMD
# 4       Intel
#         ...
# 1298    Intel
# 1299    Intel
# 1300    Intel
# 1301      AMD
# 1302    Intel
# Name: Gpu, Length: 1303, dtype: object

# %%
df['Gpu']=df['Gpu'].apply(lambda x:x.split()[0])

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: count, dtype: int64

# %%
#out of 4 catogories there is only one laptop having arm gpu
#it does not have much impact not that significant ignore that particular thing

# %%
#display the dataframe wher my df of gpu arm (gpu having arm)
df['Gpu']=='ARM'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1298    False
# 1299    False
# 1300    False
# 1301    False
# 1302    False
# Name: Gpu, Length: 1303, dtype: bool

# %%
df[df['Gpu']=='ARM'] #notation display the dataframe where the gpu matches arm
# Out:
#       Company            TypeName  Inches                 ScreenResolution  \
# 1191  Samsung  2 in 1 Convertible    12.3  IPS Panel Touchscreen 2400x1600
#
#                                 Cpu  Ram              Memory  Gpu  \
# 1191  Samsung Cortex A72&A53 2.0GHz    4  32GB Flash Storage  ARM
#
#                    OpSys  Weight     Price
# 1191  Others/Linux/No OS    1.15  35111.52

# %%
#remove this from the dataset
df=df[df['Gpu']!='ARM']  #removing whole all columns hence df

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel     722
# Nvidia    400
# AMD       180
# Name: count, dtype: int64

# %%
df['Gpu'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Gpu'>

# %%
sns.barplot(x=df['Gpu'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
df['Cpu']
# Out:
# 0                       Intel Core i5 2.3GHz
# 1                       Intel Core i5 1.8GHz
# 2                 Intel Core i5 7200U 2.5GHz
# 3                       Intel Core i7 2.7GHz
# 4                       Intel Core i5 3.1GHz
#                         ...
# 1298              Intel Core i7 6500U 2.5GHz
# 1299              Intel Core i7 6500U 2.5GHz
# 1300    Intel Celeron Dual Core N3050 1.6GHz
# 1301              Intel Core i7 6500U 2.5GHz
# 1302    Intel Celeron Dual Core N3050 1.6GHz
# Name: Cpu, Length: 1302, dtype: object

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i5 2.9GHz               1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v5 2.9GHz      1
# Name: count, Length: 117, dtype: int64

# %%
df['Cpu'].value_counts().sample(10)
# Out:
# Cpu
# Intel Atom x5-Z8300 1.44GHz               1
# Intel Core i7 7700HQ 2.8GHz             146
# Intel Core i7 2.7GHz                      1
# AMD Ryzen 1600 3.2GHz                     1
# Intel Core i7 7500U 2.7GHz              134
# Intel Core i7 8650U 1.9GHz                2
# Intel Core i7 7560U 2.4GHz                2
# Intel Celeron Quad Core N3710 1.6GHz      1
# Intel Core i7 2.8GHz                      1
# Intel Core i5 1.6GHz                      3
# Name: count, dtype: int64

# %%
#extract only these things
x = 'Intel Core i5 7200U 2.50GHz'
x.split()
# Out:
# ['Intel', 'Core', 'i5', '7200U', '2.50GHz']

# %%
#slicing
x.split()[0:3]
# Out:
# ['Intel', 'Core', 'i5']

# %%
#want this in string format use join function
" ".join(x.split()[0:3]) #using space to join  (3 words join them with space)
# Out:
# 'Intel Core i5'

# %%
" ".join(['a','b']) #(2 words join them with space)
# Out:
# 'a b'

# %%
".".join(['a','b']) #(2 words join them with dot)
# Out:
# 'a.b'

# %%
a='Intel Core i5 7200U 2.50GHz'

# %%
#apply this on whole column
#create lambda function
(lambda x:" ".join(x.split()[0:3]))(a) #pass variable
# Out:
# 'Intel Core i5'

# %%
#send value directly
(lambda x:" ".join(x.split()[0:3]))('AMD A10-Series 9620P 2.5GHz')
# Out:
# 'AMD A10-Series 9620P'

# %%
#apply this on whole column
df['Cpu'] = df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))
# Out:
# <ipython-input-77-eb059b72077c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Cpu'] = df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
df['Cpu']
#see how many catogaries are there we still have many categories
# Out:
# 0            Intel Core i5
# 1            Intel Core i5
# 2            Intel Core i5
# 3            Intel Core i7
# 4            Intel Core i5
#                ...
# 1298         Intel Core i7
# 1299         Intel Core i7
# 1300    Intel Celeron Dual
# 1301         Intel Core i7
# 1302    Intel Celeron Dual
# Name: Cpu, Length: 1302, dtype: object

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i7               527
# Intel Core i5               423
# Intel Core i3               136
# Intel Celeron Dual           80
# Intel Pentium Quad           27
# Intel Core M                 19
# AMD A9-Series 9420           12
# Intel Celeron Quad            8
# AMD A6-Series 9220            8
# AMD A12-Series 9720P          7
# Intel Atom x5-Z8350           5
# AMD A8-Series 7410            4
# Intel Atom x5-Z8550           4
# Intel Pentium Dual            3
# AMD A9-Series 9410            3
# AMD Ryzen 1700                3
# AMD A9-Series A9-9420         2
# AMD A10-Series 9620P          2
# Intel Atom X5-Z8350           2
# AMD E-Series E2-9000e         2
# Intel Xeon E3-1535M           2
# Intel Xeon E3-1505M           2
# AMD E-Series 7110             2
# AMD A6-Series A6-9220         2
# AMD A10-Series 9600P          2
# AMD A10-Series A10-9620P      2
# AMD Ryzen 1600                1
# Intel Atom x5-Z8300           1
# AMD E-Series E2-6110          1
# ...

# %%
#reduce it further
#group them into other different category
#write a function to do that
def fetch_processor(text):
  if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
    return text
  elif text.split()[0] == 'Intel':
    return 'Other Intel Processor'
  else:
    return 'AMD Processor'

# %%
#apply this function on column
df['Cpu'] = df['Cpu'].apply(fetch_processor)
# Out:
# <ipython-input-81-093e9bff72c8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Cpu'] = df['Cpu'].apply(fetch_processor)

# %%
df['Cpu']
# Out:
# 0               Intel Core i5
# 1               Intel Core i5
# 2               Intel Core i5
# 3               Intel Core i7
# 4               Intel Core i5
#                 ...
# 1298            Intel Core i7
# 1299            Intel Core i7
# 1300    Other Intel Processor
# 1301            Intel Core i7
# 1302    Other Intel Processor
# Name: Cpu, Length: 1302, dtype: object

# %%
df['Cpu'].value_counts() #5 differnet categories
# Out:
# Cpu
# Intel Core i7            527
# Intel Core i5            423
# Other Intel Processor    154
# Intel Core i3            136
# AMD Processor             62
# Name: count, dtype: int64

# %%
df['Cpu'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Cpu'>

# %%
sns.barplot(x=df['Cpu'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Feature Engineering and Feature Extraction on Screen Resolution Column
#
# Resolution-Number of pixels on the screen

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution                    Cpu  Ram  \
# 0             IPS Panel Retina Display 2560x1600          Intel Core i5    8
# 1                                       1440x900          Intel Core i5    8
# 2                              Full HD 1920x1080          Intel Core i5    8
# 3             IPS Panel Retina Display 2880x1800          Intel Core i7   16
# 4             IPS Panel Retina Display 2560x1600          Intel Core i5    8
# ...

# %%
df['ScreenResolution']
# Out:
# 0               IPS Panel Retina Display 2560x1600
# 1                                         1440x900
# 2                                Full HD 1920x1080
# 3               IPS Panel Retina Display 2880x1800
# 4               IPS Panel Retina Display 2560x1600
#                            ...
# 1298     IPS Panel Full HD / Touchscreen 1920x1080
# 1299    IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                      1366x768
# 1301                                      1366x768
# 1302                                      1366x768
# Name: ScreenResolution, Length: 1302, dtype: object

# %%
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# ...

# %%
#Touchscreen is there or not
(lambda x:1 if 'Touchscreen' in x else 0)('Touchscreen / 4K Ultra HD 3840x2160')
# Out:
# 1

# %%
#create Touchscreen column
df['Touchscreen'] = df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)
# Out:
# <ipython-input-91-d8bb29f6d73e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Touchscreen'] = df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)

# %%
df.sample(5)
# Out:
#     Company            TypeName  Inches  \
# 525  Lenovo            Notebook    14.0
# 227    Asus            Notebook    15.6
# 819    Dell            Notebook    14.0
# 755  Lenovo  2 in 1 Convertible    13.3
# 319    Acer            Notebook    11.6
#
#                                ScreenResolution                    Cpu  Ram  \
# 525                           Full HD 1920x1080          Intel Core i5    8
# 227                           Full HD 1920x1080          Intel Core i5    8
# 819                                    1366x768          Intel Core i5    4
# 755  IPS Panel Quad HD+ / Touchscreen 3200x1800          Intel Core i5    8
# 319                                    1366x768  Other Intel Processor    4
#
#                   Memory     Gpu    OpSys  Weight     Price  Touchscreen
# 525            256GB SSD   Intel  Windows    2.02  71395.20            0
# 227            256GB SSD  Nvidia  Windows    2.00  40972.32            0
# ...

# %%
df['IPS'] = df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)
# Out:
# <ipython-input-93-30d0d74fd5ed>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['IPS'] = df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)

# %%
df.sample(5)
# Out:
#      Company            TypeName  Inches  \
# 650     Asus              Gaming    17.3
# 672   Lenovo  2 in 1 Convertible    13.3
# 748     Dell            Notebook    14.0
# 445     Dell            Notebook    14.0
# 1040  Lenovo  2 in 1 Convertible    15.6
#
#                                ScreenResolution            Cpu  Ram  \
# 650                 IPS Panel Full HD 1920x1080  Intel Core i7   32
# 672   IPS Panel Full HD / Touchscreen 1920x1080  Intel Core i5    8
# 748                                    1366x768  Intel Core i5    8
# 445                           Full HD 1920x1080  Intel Core i5    8
# 1040  IPS Panel Full HD / Touchscreen 1920x1080  Intel Core i7    4
#
#          Memory     Gpu    OpSys  Weight        Price  Touchscreen  IPS
# 650   512GB SSD  Nvidia  Windows    3.80  149130.7200            0    1
# 672   256GB SSD   Intel  Windows    1.30   55091.5200            1    1
# 748   256GB SSD   Intel  Windows    1.60   60031.1088            0    0
# ...

# %%
df['Touchscreen']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1298    1
# 1299    1
# 1300    0
# 1301    0
# 1302    0
# Name: Touchscreen, Length: 1302, dtype: int64

# %%
df['Touchscreen'].value_counts()

# %%
df['Touchscreen'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Touchscreen'>

# %%
sns.barplot(x=df['Touchscreen'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
df['IPS']
# Out:
# 0       1
# 1       0
# 2       0
# 3       1
# 4       1
#        ..
# 1298    1
# 1299    1
# 1300    0
# 1301    0
# 1302    0
# Name: IPS, Length: 1302, dtype: int64

# %%
df['IPS'].value_counts()
# Out:
# IPS
# 0    938
# 1    364
# Name: count, dtype: int64

# %%
df['IPS'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='IPS'>

# %%
sns.barplot(x=df['IPS'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
df['ScreenResolution'].str.split()
# Out:
# 0                [IPS, Panel, Retina, Display, 2560x1600]
# 1                                              [1440x900]
# 2                                   [Full, HD, 1920x1080]
# 3                [IPS, Panel, Retina, Display, 2880x1800]
# 4                [IPS, Panel, Retina, Display, 2560x1600]
#                               ...
# 1298    [IPS, Panel, Full, HD, /, Touchscreen, 1920x1080]
# 1299    [IPS, Panel, Quad, HD+, /, Touchscreen, 3200x1...
# 1300                                           [1366x768]
# 1301                                           [1366x768]
# 1302                                           [1366x768]
# Name: ScreenResolution, Length: 1302, dtype: object

# %%
df['ScreenResolution'].str.split()[0]
# Out:
# ['IPS', 'Panel', 'Retina', 'Display', '2560x1600']

# %%
df['ScreenResolution'].str.split()[0][-1]
# Out:
# '2560x1600'

# %%
df['ScreenResolution'].str.split()[0][-1].split('x')
# Out:
# ['2560', '1600']

# %%
df['ScreenResolution'].str.split()[0][-1].split('x')[0]
# Out:
# '2560'

# %%
df['ScreenResolution'].str.split()[0][-1].split('x')[1]
# Out:
# '1600'

# %%
x_r=[]
y_r=[]
for i in range(len(df)):
  x_r.append(df['ScreenResolution'].str.split()[i][-1].split('x')[0])
  y_r.append(df['ScreenResolution'].str.split()[i][-1].split('x')[1])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1191
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-115-2a157ed04089> in <cell line: 3>()
#       2 y_r=[]
#       3 for i in range(len(df)):
# ...

# %%
# x_r=[]
# y_r=[]
# for index, row in df.iterrows():
#   resolution = row['ScreenResolution']
#   try:
#     width, height = resolution.split('x')  # Split resolution directly
#     x_r.append(width)
#     y_r.append(height)
#   except (AttributeError, ValueError):
#     # Handle cases where 'ScreenResolution' is not a string or doesn't contain 'x'
#     x_r.append(None)  # Or any other suitable default value
#     y_r.append(None)  # Or any other suitable default value

# %%
#Alternate method 2
new=df['ScreenResolution'].str.split('x',n=1,expand=True)

# %%
df['X_res']=new[0]
df['Y_res']=new[1]
# Out:
# <ipython-input-119-727b90e5e258>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['X_res']=new[0]
# <ipython-input-119-727b90e5e258>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Y_res']=new[1]

# %%
df.head(3)
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
#
#              Cpu  Ram               Memory    Gpu               OpSys  Weight  \
# 0  Intel Core i5    8            128GB SSD  Intel              Mac OS    1.37
# 1  Intel Core i5    8  128GB Flash Storage  Intel              Mac OS    1.34
# 2  Intel Core i5    8            256GB SSD  Intel  Others/Linux/No OS    1.86
#
#         Price  Touchscreen  IPS                          X_res Y_res
# 0  71378.6832            0    1  IPS Panel Retina Display 2560  1600
# 1  47895.5232            0    0                           1440   900
# 2  30636.0000            0    0                   Full HD 1920  1080

# %%
df['X_res']=df['X_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])
# Out:
# <ipython-input-124-e9f464175c79>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['X_res']=df['X_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
df['X_res']=df['X_res'].astype('int')
df['Y_res']=df['Y_res'].astype('int')
# Out:
# <ipython-input-125-d9deaeb7ef96>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['X_res']=df['X_res'].astype('int')
# <ipython-input-125-d9deaeb7ef96>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Y_res']=df['Y_res'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1302 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1302 non-null   object
#  1   TypeName          1302 non-null   object
#  2   Inches            1302 non-null   float64
#  3   ScreenResolution  1302 non-null   object
#  4   Cpu               1302 non-null   object
#  5   Ram               1302 non-null   int64
#  6   Memory            1302 non-null   object
#  7   Gpu               1302 non-null   object
#  8   OpSys             1302 non-null   object
#  9   Weight            1302 non-null   float64
#  10  Price             1302 non-null   float64
#  11  Touchscreen       1302 non-null   int64
#  12  IPS               1302 non-null   int64
#  13  X_res             1302 non-null   int64
#  14  Y_res             1302 non-null   int64
# dtypes: float64(3), int64(5), object(7)
# memory usage: 195.0+ KB

# %%
#df.corr()['Price']
import pandas as pd
import numpy as np

# Assuming 'Company' is the column containing "Apple" and other non-numeric values
# Select only numeric columns for correlation calculation
numeric_df = df.select_dtypes(include=np.number)

# Calculate correlation
correlation = numeric_df.corr()['Price']

print(correlation)
# Out:
# Inches         0.067329
# Ram            0.742905
# Weight         0.209867
# Price          1.000000
# Touchscreen    0.192917
# IPS            0.253320
# X_res          0.557369
# Y_res          0.554591
# Name: Price, dtype: float64

# %%
# ppi=sqrt((w^2+h^2))/d
#df['ppi']=(((df['X_res']**2)+(df['Y_res']**2))**0.5/df['Inches']).astype('float')
df['ppi'] = (((df['X_res']**2)+(df['Y_res']**2))**0.5/df['Inches']).astype('float')
# Out:
# <ipython-input-131-cd47d7d433f9>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ppi'] = (((df['X_res']**2)+(df['Y_res']**2))**0.5/df['Inches']).astype('float')

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#              Cpu  Ram               Memory    Gpu               OpSys  Weight  \
# 0  Intel Core i5    8            128GB SSD  Intel              Mac OS    1.37
# 1  Intel Core i5    8  128GB Flash Storage  Intel              Mac OS    1.34
# 2  Intel Core i5    8            256GB SSD  Intel  Others/Linux/No OS    1.86
# 3  Intel Core i7   16            512GB SSD    AMD              Mac OS    1.83
# 4  Intel Core i5    8            256GB SSD  Intel              Mac OS    1.37
#
#          Price  Touchscreen  IPS  X_res  Y_res         ppi
# ...

# %%
df.drop(columns=['Inches','X_res','Y_res','ScreenResolution'],inplace=True) #cleanse the data
# Out:
# <ipython-input-134-f0ee6188ccca>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Inches','X_res','Y_res','ScreenResolution'],inplace=True) #cleanse the data

# %%
df.head()
# Out:
#   Company   TypeName            Cpu  Ram               Memory    Gpu  \
# 0   Apple  Ultrabook  Intel Core i5    8            128GB SSD  Intel
# 1   Apple  Ultrabook  Intel Core i5    8  128GB Flash Storage  Intel
# 2      HP   Notebook  Intel Core i5    8            256GB SSD  Intel
# 3   Apple  Ultrabook  Intel Core i7   16            512GB SSD    AMD
# 4   Apple  Ultrabook  Intel Core i5    8            256GB SSD  Intel
#
#                 OpSys  Weight        Price  Touchscreen  IPS         ppi
# 0              Mac OS    1.37   71378.6832            0    1  226.983005
# 1              Mac OS    1.34   47895.5232            0    0  127.677940
# 2  Others/Linux/No OS    1.86   30636.0000            0    0  141.211998
# 3              Mac OS    1.83  135195.3360            0    1  220.534624
# 4              Mac OS    1.37   96095.8080            0    1  226.983005

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                37
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
df.drop(columns=['Memory'],inplace=True)
# Out:
# <ipython-input-138-8cab1fd6fcc0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Memory'],inplace=True)

# %% [markdown]
# Segregation into(of) input and output

# %%
X=df.drop(columns=['Price'])
y=df['Price']

# %%
#data of price skewed towards the left
#less normal
sns.distplot(df['Price'])
plt.show()
# Out:
# <ipython-input-141-ae0ca8faf0cb>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'])

# %%
#not skewed apply log transformation np.log in the center price more towards the center
#convert that range to range of log values normal distributed values
#data tends to give better results when it is skewed towards middle or normal distributed values
#data is following normal distribution curve
sns.distplot(np.log(df['Price']))
# Out:
# <ipython-input-142-3a2fa4f51fe0>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['Price']))
# <Axes: xlabel='Price', ylabel='Density'>

# %%
X=df.drop(columns=['Price'])
y=np.log(df['Price'])

# %%
X
# Out:
#      Company            TypeName                    Cpu  Ram    Gpu  \
# 0      Apple           Ultrabook          Intel Core i5    8  Intel
# 1      Apple           Ultrabook          Intel Core i5    8  Intel
# 2         HP            Notebook          Intel Core i5    8  Intel
# 3      Apple           Ultrabook          Intel Core i7   16    AMD
# 4      Apple           Ultrabook          Intel Core i5    8  Intel
# ...      ...                 ...                    ...  ...    ...
# 1298  Lenovo  2 in 1 Convertible          Intel Core i7    4  Intel
# 1299  Lenovo  2 in 1 Convertible          Intel Core i7   16  Intel
# 1300  Lenovo            Notebook  Other Intel Processor    2  Intel
# 1301      HP            Notebook          Intel Core i7    6    AMD
# 1302    Asus            Notebook  Other Intel Processor    4  Intel
#
#                    OpSys  Weight  Touchscreen  IPS         ppi
# 0                 Mac OS    1.37            0    1  226.983005
# ...

# %%
y
# Out:
# 0       11.175755
# 1       10.776777
# 2       10.329931
# 3       11.814476
# 4       11.473101
#           ...
# 1298    10.433899
# 1299    11.288115
# 1300     9.409283
# 1301    10.614129
# 1302     9.886358
# Name: Price, Length: 1302, dtype: float64

# %% [markdown]
# Divide the data into train and test
#
# 85% of data for training and 15% for testing
#
# Can't directly take first 85 as training brcause data will be ordered should take random data to be effective randomly pick

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.15,random_state=2)# 2values distributed into 4 values

# %%
X.shape
# Out:
# (1302, 10)

# %%
X_train.shape
# Out:
# (1106, 10)

# %%
X_test.shape
# Out:
# (196, 10)

# %% [markdown]
# Column Transformer Algorithm

# %%
from sklearn.compose import ColumnTransformer  #multiple different tasks can be done it applies transformers to columns of an array or pandas dataframe
from sklearn.preprocessing import OneHotEncoder  #non numerical columns can be converted into numerical columns
from sklearn.pipeline import Pipeline  #combine multiple steps
from sklearn.metrics import r2_score,mean_absolute_error #

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR

# %%
step1=ColumnTransformer(transformers=[
  ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])
    ],remainder='passthrough')
step2=LinearRegression()

pipe=Pipeline([('step1',step1),('step2',step2)])

pipe.fit(X_train,y_train)

y_pred=pipe.predict(X_test)

print("R2 score=",r2_score(y_test,y_pred))
print("MAE=",mean_absolute_error(y_test,y_pred))
# Out:
# R2 score= 0.8031269075997791
# MAE= 0.21675179470046485

# %%
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])
    ],remainder='passthrough')
step2=KNeighborsRegressor(n_neighbors=3)

pipe=Pipeline([('step1',step1),('step2',step2)])

pipe.fit(X_train,y_train)

y_pred=pipe.predict(X_test)

print("R2 score=",r2_score(y_test,y_pred))
print("MAE=",mean_absolute_error(y_test,y_pred))
# Out:
# R2 score= 0.8556359048602785
# MAE= 0.18195695113410748

# %%
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])
    ],remainder='passthrough')
step2=DecisionTreeRegressor(max_depth=8)

pipe=Pipeline([('step1',step1),('step2',step2)])

pipe.fit(X_train,y_train)

y_pred=pipe.predict(X_test)

print("R2 score=",r2_score(y_test,y_pred))
print("MAE=",mean_absolute_error(y_test,y_pred))
# Out:
# R2 score= 0.8207126731886029
# MAE= 0.1935322643418581

# %%
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])
    ],remainder='passthrough')
step2=SVR(kernel='rbf',C=10000)

pipe=Pipeline([('step1',step1),('step2',step2)])

pipe.fit(X_train,y_train)

y_pred=pipe.predict(X_test)

print("R2 score=",r2_score(y_test,y_pred))
print("MAE=",mean_absolute_error(y_test,y_pred))
# Out:
# R2 score= 0.8406207659234866
# MAE= 0.19132591223569498
