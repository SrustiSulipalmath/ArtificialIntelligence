# %%
import numpy as np

# %%
arr1=np.array([2,4,6,8,9])

# %%
arr1
# Out:
# array([2, 4, 6, 8, 9])

# %%
list=[2,4,6,7,8]

# %%
list
# Out:
# [2, 4, 6, 7, 8]

# %%
print(arr1)
# Out:
# [2 4 6 8 9]

# %%
type(arr1)
# Out:
# numpy.ndarray

# %%
len(arr1)
# Out:
# 5

# %%
arr1[0]
# Out:
# 2

# %%
arr1[0:3]
# Out:
# array([2, 4, 6])

# %%
arr1[-3]
# Out:
# 6

# %%
arr1
# Out:
# array([2, 4, 6, 8, 9])

# %%
arr1.shape
# Out:
# (5,)

# %%
arr1.size
# Out:
# 5

# %%
arr1.ndim
# Out:
# 1

# %%
arr2 =np.array([[1,2,3],[4,5,6]])

# %%
arr2
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
arr3 =np.array([[4,5,6],[7,8,9]])

# %%
arr3
# Out:
# [[4, 5, 6], [7, 8, 9]]

# %%
arr2.ndim
# Out:
# 2

# %%
arr3.ndim
# Out:
# 2

# %%
arr3.shape
# Out:
# (2, 3)

# %%
arr3.size
# Out:
# 6

# %%
arr1.dtype
# Out:
# dtype('int64')

# %%
arr2.shape
# Out:
# (2, 3)

# %%
arr3 = arr2.reshape(3,2)

# %%
arr3.shape
# Out:
# (3, 2)

# %%
np.random.randint(4,9)
# Out:
# 5

# %%
np.random.randint(0,100,5)
# Out:
# array([22, 40, 42, 52,  3])

# %%
np.random.randint(0,9,6)
# Out:
# array([2, 1, 1, 2, 1, 0])

# %%
print(np.random.randint(0,9,6))
# Out:
# [7 5 5 4 0 7]

# %%
np.random.randint(0,15,20)
# Out:
# array([ 2,  2,  1,  6,  2,  1,  7,  9, 10, 12,  0, 14, 13,  9,  2,  9,  7,
#         7, 14,  3])

# %%
np.random.seed(13)
np.random.randint(0,15,20)
# Out:
# array([ 2,  0, 10,  0,  6,  2,  4,  9, 12, 10,  3, 10,  4, 14,  2, 14,  6,
#         5, 13, 10])

# %%
a=np.random.randint(0,15,20)

# %%
a = np.sort(a)
# Out:
# array([ 0,  1,  2,  2,  3,  3,  4,  5,  5,  6,  8,  8,  9, 10, 11, 11, 11,
#        11, 12, 12])

# %%
b = np.flip(a)

# %%
b
# Out:
# array([10, 12,  8, 11, 12,  8,  2,  1, 11,  5,  6, 11,  3,  5,  3,  0,  2,
#         4, 11,  9])

# %%
np.sum(a)
# Out:
# 134

# %%
np.mean(a)
# Out:
# 6.7

# %%
np.unique(a)
# Out:
# array([ 0,  1,  2,  3,  4,  5,  6,  8,  9, 10, 11, 12])

# %%
np.unique(a,return_counts=True)
# Out:
# (array([ 0,  1,  2,  3,  4,  5,  6,  8,  9, 10, 11, 12]),
#  array([1, 1, 2, 2, 1, 2, 1, 2, 1, 1, 4, 2]))

# %%
np.random.seed(2)
np.random.randint(0,10,6)
# Out:
# array([8, 8, 6, 2, 8, 7])

# %%
np.random.randint(0,10,(3,2))
# Out:
# array([[2, 1],
#        [5, 4],
#        [4, 5]])

# %%
np.random.randint(0,10,(2,3))
# Out:
# array([[7, 3, 6],
#        [4, 3, 7]])

# %%
np.arange(0,10,6)
# Out:
# array([0, 6])

# %%
np.arange(0,5,1)
# Out:
# array([0, 1, 2, 3, 4])

# %%
np.arange(0,6,1).reshape(2,3)
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %%
np.arange(3,16,4)
# Out:
# array([ 3,  7, 11, 15])

# %%
np.arange(18,5,-3)
# Out:
# array([18, 15, 12,  9,  6])

# %%
for i in range(18,5,-3):
  print(i)
# Out:
# 18
# 15
# 12
# 9
# 6
