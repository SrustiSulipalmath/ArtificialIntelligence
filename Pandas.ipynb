# %%
import pandas as pd
import numpy as np

# %%
s1=np.array([2,4,6,8,5])

# %%
type(s1)
# Out:
# numpy.ndarray

# %%
s1
# Out:
# array([2, 4, 6, 8, 5])

# %%
pd.Series(s1)
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# 4    5
# dtype: int64

# %%
a1=pd.Series(s1)

# %%
a1
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# 4    5
# dtype: int64

# %%
type(a1)
# Out:
# pandas.core.series.Series

# %%
names=['Alpha','Bravo','Charlie','Delta','Echo']
a1=pd.Series(s1,index=names)
a1
# Out:
# Alpha      2
# Bravo      4
# Charlie    6
# Delta      8
# Echo       5
# dtype: int64

# %%
a1['Alpha']
# Out:
# 2

# %%
a1.values
# Out:
# array([2, 4, 6, 8, 5])

# %%
a1.index
# Out:
# Index(['Alpha', 'Bravo', 'Charlie', 'Delta', 'Echo'], dtype='object')

# %%
list1=['jack','john','jacob','juliet','jessica']
pd.Series(list1,index=['First','Second','Third','Fourth','Fifth'])
# Out:
# First        jack
# Second       john
# Third       jacob
# Fourth     juliet
# Fifth     jessica
# dtype: object

# %%
d1={'a':5,'b':3,'c':6,'d':9,'e':4}
pd.Series(d1)
# Out:
# a    5
# b    3
# c    6
# d    9
# e    4
# dtype: int64

# %% [markdown]
# # DataFrames

# %%
d2={'Cars':['Volvo','Ferrari','Lamborghini'],'Sales':[32,25,12]}
df1=pd.DataFrame(d2)
df1
# Out:
#           Cars  Sales
# 0        Volvo     32
# 1      Ferrari     25
# 2  Lamborghini     12

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Cars    3 non-null      object
#  1   Sales   3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 176.0+ bytes

# %%
df1.min()
# Out:
# Cars     Ferrari
# Sales         12
# dtype: object

# %%
df1.max()
# Out:
# Cars     Volvo
# Sales       32
# dtype: object

# %%
np.random.seed()
np.random.randint(20,50,20)
# Out:
# array([48, 27, 41, 34, 34, 28, 26, 45, 34, 39, 37, 47, 39, 22, 38, 48, 34,
#        22, 45, 32])

# %%
np.random.seed()
np.random.randint(20,50,(5,4))
# Out:
# array([[33, 23, 25, 34],
#        [37, 25, 20, 26],
#        [36, 35, 32, 26],
#        [46, 48, 39, 23],
#        [31, 24, 33, 40]])

# %%
np.random.seed()
marks = np.random.randint(20,50,(5,4))
marks
# Out:
# array([[25, 25, 26, 49],
#        [45, 28, 33, 34],
#        [42, 28, 43, 43],
#        [44, 31, 21, 39],
#        [44, 31, 24, 48]])

# %%
df=pd.DataFrame(marks)
df
# Out:
#     0   1   2   3
# 0  25  25  26  49
# 1  45  28  33  34
# 2  42  28  43  43
# 3  44  31  21  39
# 4  44  31  24  48

# %%
Students =['jim','mike','lily','rose','eve']
Subjects=['maths','science','social','english']
df=pd.DataFrame(marks,index=Students,columns=Subjects)
df
# Out:
#       maths  science  social  english
# jim      25       25      26       49
# mike     45       28      33       34
# lily     42       28      43       43
# rose     44       31      21       39
# eve      44       31      24       48

# %%
df['social']
# Out:
# jim     26
# mike    33
# lily    43
# rose    21
# eve     24
# Name: social, dtype: int64

# %%
df.sum()
# Out:
# maths      200
# science    143
# social     147
# english    213
# dtype: int64

# %%
df.sum(axis=0)
# Out:
# maths      200
# science    143
# social     147
# english    213
# dtype: int64

# %%
df.sum(axis=1)
# Out:
# jim     125
# mike    140
# lily    156
# rose    135
# eve     147
# dtype: int64

# %%
df.mean()
# Out:
# maths      40.0
# science    28.6
# social     29.4
# english    42.6
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# jim     31.25
# mike    35.00
# lily    39.00
# rose    33.75
# eve     36.75
# dtype: float64

# %%
df['Total']=df.sum(axis=1)
df
# Out:
#       maths  science  social  english  Total
# jim      25       25      26       49    125
# mike     45       28      33       34    140
# lily     42       28      43       43    156
# rose     44       31      21       39    135
# eve      44       31      24       48    147

# %%
df['Total_Marks']=df['maths']+df['science']+df['social']+df['english']
df
# Out:
#       maths  science  social  english  Total  Total_Marks
# jim      25       25      26       49    125          125
# mike     45       28      33       34    140          140
# lily     42       28      43       43    156          156
# rose     44       31      21       39    135          135
# eve      44       31      24       48    147          147

# %%
df.plot()
# Out:
# <Axes: >

# %%
df['Percentage']=(df['Total']/200)*100
df
# Out:
#       maths  science  social  english  Total  Percentage
# jim      25       25      26       49    125        62.5
# mike     45       28      33       34    140        70.0
# lily     42       28      43       43    156        78.0
# rose     44       31      21       39    135        67.5
# eve      44       31      24       48    147        73.5

# %%
df=df.drop('Total_Marks',axis=1)
df
# Out:
#       maths  science  social  english  Total  Percentage
# jim      25       25      26       49  125.0        62.5
# mike     45       28      33       34  140.0        70.0
# lily     42       28      43       43  156.0        78.0
# rose     44       31      21       39  135.0        67.5
# eve      44       31      24       48  147.0        73.5

# %%
df=df.drop('Total_Marks',axis=1,inplace=True)

# %%
df
# Out:
#       maths  science  social  english  Total  Percentage
# jim      25       25      26       49    125        62.5
# mike     45       28      33       34    140        70.0
# lily     42       28      43       43    156        78.0
# rose     44       31      21       39    135        67.5
# eve      44       31      24       48    147        73.5

# %%
df=df.drop('mike',axis=0)
df
# Out:
#       maths  science  social  english  Total  Percentage
# jim      25       25      26       49    125        62.5
# lily     42       28      43       43    156        78.0
# rose     44       31      21       39    135        67.5
# eve      44       31      24       48    147        73.5

# %%
d3= {'Football' :[9,    5,    np.nan, np.nan,   2,    1,        9,      6],
     'Tennis'   :[3,    6,          9,    4,    7,    3,        5,      2],
     'Cricket'  :[9,    7,    np.nan,     3,    1,    8,    np.nan,     3]
     }
d3
# Out:
# {'Football': [9, 5, nan, nan, 2, 1, 9, 6],
#  'Tennis': [3, 6, 9, 4, 7, 3, 5, 2],
#  'Cricket': [9, 7, nan, 3, 1, 8, nan, 3]}

# %%
df2=pd.DataFrame(d3)
df2
# Out:
#    Football  Tennis  Cricket
# 0       9.0       3      9.0
# 1       5.0       6      7.0
# 2       NaN       9      NaN
# 3       NaN       4      3.0
# 4       2.0       7      1.0
# 5       1.0       3      8.0
# 6       9.0       5      NaN
# 7       6.0       2      3.0

# %%
df2.isnull()
# Out:
#    Football  Tennis  Cricket
# 0     False   False    False
# 1     False   False    False
# 2      True   False     True
# 3      True   False    False
# 4     False   False    False
# 5     False   False    False
# 6     False   False     True
# 7     False   False    False

# %%
df2.isnull().sum()
# Out:
# Football    2
# Tennis      0
# Cricket     2
# dtype: int64

# %%
df2.dropna(axis=0)
# Out:
#    Football  Tennis  Cricket
# 0       9.0       3      9.0
# 1       5.0       6      7.0
# 4       2.0       7      1.0
# 5       1.0       3      8.0
# 7       6.0       2      3.0

# %%
df2.dropna(axis=1)
# Out:
#    Tennis
# 0       3
# 1       6
# 2       9
# 3       4
# 4       7
# 5       3
# 6       5
# 7       2

# %%
df2.fillna(value=0)
# Out:
#    Football  Tennis  Cricket
# 0       9.0       3      9.0
# 1       5.0       6      7.0
# 2       0.0       9      0.0
# 3       0.0       4      3.0
# 4       2.0       7      1.0
# 5       1.0       3      8.0
# 6       9.0       5      0.0
# 7       6.0       2      3.0

# %%
df2
# Out:
#    Football  Tennis  Cricket
# 0       9.0       3      9.0
# 1       5.0       6      7.0
# 2       NaN       9      NaN
# 3       NaN       4      3.0
# 4       2.0       7      1.0
# 5       1.0       3      8.0
# 6       9.0       5      NaN
# 7       6.0       2      3.0

# %%
df2['Football'].mean()
# Out:
# 5.333333333333333

# %%
df2['Football'].median()
# Out:
# 5.5

# %%
df2['Football'].mode()
# Out:
# 0    9.0
# Name: Football, dtype: float64

# %%
df2['Football']=df2['Football'].fillna(value=df2['Football'].mean())
df2
# Out:
#    Football  Tennis  Cricket
# 0  9.000000       3      9.0
# 1  5.000000       6      7.0
# 2  5.333333       9      NaN
# 3  5.333333       4      3.0
# 4  2.000000       7      1.0
# 5  1.000000       3      8.0
# 6  9.000000       5      NaN
# 7  6.000000       2      3.0

# %%
df2['Cricket']=df2['Cricket'].fillna(value=df2['Cricket'].median())
df2
# Out:
#    Football  Tennis  Cricket
# 0  9.000000       3      9.0
# 1  5.000000       6      7.0
# 2  5.333333       9      5.0
# 3  5.333333       4      3.0
# 4  2.000000       7      1.0
# 5  1.000000       3      8.0
# 6  9.000000       5      5.0
# 7  6.000000       2      3.0
